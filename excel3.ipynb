# %%
import pandas as pd 
df=pd.read_excel(r"C:\Users\Asus\Desktop\thiscode\file_2024_t1.xlsx",sheet_name='Sheet1')

# %%
df.head()
# Out:
#                 Time  Temp°C  HumiRH
# 0  24/01/01 00:32:58    20.3    57.8
# 1  24/01/01 01:02:58    20.1    57.8
# 2  24/01/01 01:32:58    19.8    57.7
# 3  24/01/01 02:02:58    19.8    57.7
# 4  24/01/01 02:32:58    19.6    58.1

# %%
def convert_date_format(dt_str):
    dt = pd.to_datetime(dt_str, format='mixed', dayfirst=True)
    dt = dt.replace(month=1)
    return dt.strftime('%d/%m/%y %H:%M:%S')
def clearData():
    df['Time'] = df['Time'].apply(convert_date_format)
    df['Time'].head()

# %%
df.to_excel('file_2024_t1.xlsx', index=False)
