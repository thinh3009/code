# %% [markdown]
# * n la so le(odd) in ra weird
# * n la so chan(even) va trong khoang 2 den 5 Not weird
# * n la so chan(even) va nam trong khoang 6 den 20 in weird
# * n la chan va lon hon 20 print not weird

# %%
n=int(input("Nhap: "))
if(n<=6 and n>=20):
    print("Weird")
elif(n%2==0 and n>20):
    print("Not Weird")
elif(n>=2 and n<=5):
    print("Not Weird")
else:
    print("Weird")
# Out:
# Not Weird

# %%
n=int(input("nhap: "))
if n % 2 != 0: print('Weird')

elif 2 <= n <= 5 : print('not Weird')

elif 6 <= n <= 20: print('Weird')

else: print('NOT Weird')
# Out:
# Weird
