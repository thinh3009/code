# %%
import pandas as pd
df=pd.read_excel("D:\hoc\powwerbi\Sales_demo_DB.xlsx")
df
# Out:
#               Date  ProductID  CustomerID  SalespersonID  BusinessUnitID  \
# 0       2016-01-30       1519       10290           88.0               1
# 1       2016-04-29       1519       10290           88.0               1
# 2       2017-07-13       1519       10290           88.0               1
# 3       2018-12-04       1523       16484          189.0               1
# 4       2018-12-04       1524       16484          189.0               1
# ...            ...        ...         ...            ...             ...
# 127415  2018-12-22       8631       12093          181.0              22
# 127416  2018-12-29       8631       14601          181.0              22
# 127417  2018-12-19       8632        6403          181.0              22
# 127418  2018-12-28       8634        2053          117.0              22
# 127419  2018-12-29       8634       14601          181.0              22
#
#            Revenue        Cost  Gross Profit Scenario
# ...

# %%
print(df.shape)
# Out:
# (127420, 9)
