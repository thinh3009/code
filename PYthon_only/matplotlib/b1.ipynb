# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot();

# %%
x=[1,2,3,4]
y=[10,8,5,9]
plt.plot(x,y,color='red');

# %% [markdown]
# # pyplot API

# %%
x=np.linspace()
