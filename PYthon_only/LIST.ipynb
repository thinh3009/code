# %%
lst=[1,3,4,5,6,4,4,5,6,5,'python','python']
dem=lst.count('python')
print(dem)
lst.reverse()
print(lst)
# Out:
# 2
# ['python', 'python', 5, 6, 5, 4, 4, 6, 5, 4, 3, 1]

# %%
#tim kiem gia tri trong list
lst=[1,3,4,5,6,4,4,5,6,5,'python','python']
print(lst.index('python'))
lst2=['go home']
lst.extend(lst2)
print(lst)
# Out:
# 10
# [1, 3, 4, 5, 6, 4, 4, 5, 6, 5, 'python', 'python', 'go home']

# %%
from random import  randrange
lst=[]
for i in range (1,100):
    lst.append(randrange(i))
print(lst)
# Out:
# [0, 0, 1, 3, 3, 3, 3, 3, 4, 1, 10, 3, 9, 7, 13, 4, 15, 4, 7, 15, 2, 7, 17, 12, 6, 4, 16, 3, 1, 26, 2, 11, 32, 19, 29, 13, 35, 29, 30, 8, 22, 3, 0, 20, 43, 10, 23, 27, 21, 40, 50, 4, 7, 49, 53, 35, 27, 21, 36, 6, 13, 47, 41, 15, 28, 65, 54, 66, 61, 0, 22, 20, 67, 40, 60, 38, 75, 26, 38, 5, 72, 38, 30, 1, 52, 16, 23, 51, 35, 83, 62, 40, 34, 30, 79, 40, 43, 96, 81]

# %% [markdown]
# * bai tap thuc hanh

# %% [markdown]
# 1. viet chuong trinh nhap danh sach list co:
# - tao ra 1 list moi binh phuong cac phan tu
# - xac dinh co bao nhieu ptu lon hon 50

# %%
n = int(input("Nhập số phần tử của list: "))
lst = []
for i in range(n):
    val = input(f'Nhập giá trị thứ {i+1}: ')
    lst.append(val)
print(lst)
lst2=[]
for i in lst:
    lst2.append(int(i)**2)
print(lst2)
dem=0
for l in lst2:
    if int(l)>50:
        dem+=1
print(f'co {dem} phan tu lon hon 50')
# Out:
# ['45', '56']
# [2025, 3136]
# co 2 phan tu lon hon 50

# %% [markdown]
# 2. viet chuong trinh nhap vao 1 list
# - in ra co bao nhieu so nho hon 5
# - in ra vi tri index cua so do

# %%
from random import *
n = int(input("Nhập số phần tử của list: "))
lst = []
for i in range(n):
    val = input(f'Nhập giá trị thứ {i+1}: ')
    lst.append(val)
print(lst)
dem=0
for i in lst:
    if int(i)<5:
        dem+=1
print(f'co {dem} phan tu nho hon 5')
lstIn=[]
dem=0
for j  in range(len(lst)):
    if int(lst[j])<5:
        dem+=1
        lstIn.append(j)
print('vi tri nho hon 5',lstIn)
# Out:
# ['1', '2', '3', '4', '5']
# co 4 phan tu nho hon 5
# vi tri nho hon 5 [0, 1, 2, 3]

# %% [markdown]
# 3. viet chuong trinh in so lon thu 2 va so nho thu 2
# - in ra vi tri index
