# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
df=pd.read_excel("C:\\Users\\buidu\\OneDrive\\Máy tính\\thisCode\\code\\PYthon_only\\task2\\IT Operation.xlsx")
df
# Out:
#                            Task ID  \
# 0     yZ7MKKmfmkW7F17FpQk7pMkAAldv
# 1     _98BmlWNSky-H-3b7cJphskAP0si
# 2     RsSYhYMSSEevknM1lziKd8kADSNi
# 3     DLIpJNhmqkiqfgUEt8AZtckALkzn
# 4     ghL0FByfsEWVIkGqKmMwlckADD7g
# ...                            ...
# 1177  LTeUWl3LvESweZF9C2RgJskALj7C
# 1178  z6MFfU4IMUa7nAICaxenCskADUvx
# 1179  c0-k_AfbBESoHO_29U4WN8kABsdq
# 1180  5ZMM9GC86UG8T1x9UfEFLckAN6NQ
# 1181  8UsYELtkfk2CDuyKjHMj6MkAJpVX
#
#                                               Task Name  \
# 0          Ticket(478), GLC HỌP THÁNG DUC THÁNG 02.2024
# 1     Ticket(476), Họp review phần ngôn ngữ tiếng An...
# 2                  Ticket(475), Họp TF dự án trồng rừng
# 3                  Ticket(473), <pepsict>Kiểm tra email
# 4     Ticket(470), [Smartport] Triển khai dịch vụ bả...
# ...                                                 ...
# 1177                      Triển khai Planner phòng ITHO
# 1178             Rà soát, sắp xếp lại Rack phòng Server
# ...

# %%
df.describe()
# Out:
#                              Task ID         Task Name      Bucket Name  \
# count                           1182              1182             1182
# unique                          1182               923               20
# top     yZ7MKKmfmkW7F17FpQk7pMkAAldv  Check DB system   Meeting Support
# freq                               1                90              361
#
#          Progress Priority Assigned To            Created By Created Date  \
# count        1182     1182        1160                  1182         1182
# unique          3        4          40                    12          138
# top     Completed   Medium   IT/TuanPA  Gemadept IT Helpdesk   11/07/2023
# freq         1156     1124         375                   503           26
#
#         Start Date    Due Date Is Recurring   Late Completed Date  \
# count          840        1157         1182   1182           1156
# unique         148         166            2      2            139
# ...

# %%
df.head()
# Out:
#                         Task ID  \
# 0  yZ7MKKmfmkW7F17FpQk7pMkAAldv
# 1  _98BmlWNSky-H-3b7cJphskAP0si
# 2  RsSYhYMSSEevknM1lziKd8kADSNi
# 3  DLIpJNhmqkiqfgUEt8AZtckALkzn
# 4  ghL0FByfsEWVIkGqKmMwlckADD7g
#
#                                            Task Name      Bucket Name  \
# 0       Ticket(478), GLC HỌP THÁNG DUC THÁNG 02.2024  Meeting Support
# 1  Ticket(476), Họp review phần ngôn ngữ tiếng An...           Ticket
# 2               Ticket(475), Họp TF dự án trồng rừng  Meeting Support
# 3               Ticket(473), <pepsict>Kiểm tra email         Waitlist
# 4  Ticket(470), [Smartport] Triển khai dịch vụ bả...           Ticket
#
#       Progress Priority Assigned To            Created By Created Date  \
# 0  In progress   Medium   IT/TuanPA  Gemadept IT Helpdesk   02/26/2024
# 1  In progress   Medium  IT/QuangHT  Gemadept IT Helpdesk   02/26/2024
# 2  In progress   Medium   IT/TuanPA  Gemadept IT Helpdesk   02/26/2024
# ...

# %% [markdown]
# * replace Ticket

# %%
df['Task Name']=df['Task Name'].str.replace('Ticket', '')

# %%
df['Task Name'].head()
# Out:
# 0               (478), GLC HỌP THÁNG DUC THÁNG 02.2024
# 1    (476), Họp review phần ngôn ngữ tiếng Anh trên...
# 2                       (475), Họp TF dự án trồng rừng
# 3                       (473), <pepsict>Kiểm tra email
# 4    (470), [Smartport] Triển khai dịch vụ bảo trì ...
# Name: Task Name, dtype: object

# %% [markdown]
# * replace number of string type

# %%
df['Task Name']=df['Task Name'].replace(r'\b\d+\b', '', regex=True)

# %% [markdown]
# * replace '()' in dataframe

# %%
df['Task Name']=df['Task Name'].replace(r'\(\)', '', regex=True)

# %%
df['Task Name'].head()
# Out:
# 0                          , GLC HỌP THÁNG DUC THÁNG .
# 1    , Họp review phần ngôn ngữ tiếng Anh trên webs...
# 2                            , Họp TF dự án trồng rừng
# 3                            , <pepsict>Kiểm tra email
# 4    , [Smartport] Triển khai dịch vụ bảo trì SMP v...
# Name: Task Name, dtype: object

# %% [markdown]
# * replace firt comma in dataframe

# %%
df['Task Name'].replace(r'^([^,]*),', r'\1', regex=True)
# Out:
# 0                               GLC HỌP THÁNG DUC THÁNG .
# 1        Họp review phần ngôn ngữ tiếng Anh trên websi...
# 2                                 Họp TF dự án trồng rừng
# 3                                 <pepsict>Kiểm tra email
# 4        [Smartport] Triển khai dịch vụ bảo trì SMP và...
#                               ...
# 1177                        Triển khai Planner phòng ITHO
# 1178                Rà soát sắp xếp lại Rack phòng Server
# 1179       Hướng dẫn quy trình kết nối EDO cho IT PIP/BDP
# 1180    Hướng dẫn TTS thay đổi giao diện cài đặt plugi...
# 1181            Triển khai WS Lập kế hoạch với Ms Planner
# Name: Task Name, Length: 1182, dtype: object

# %%
df['Task Name'].head()
# Out:
# 0                          , GLC HỌP THÁNG DUC THÁNG .
# 1    , Họp review phần ngôn ngữ tiếng Anh trên webs...
# 2                            , Họp TF dự án trồng rừng
# 3                            , <pepsict>Kiểm tra email
# 4    , [Smartport] Triển khai dịch vụ bảo trì SMP v...
# Name: Task Name, dtype: object

# %%
df.head()
# Out:
#                         Task ID  \
# 0  yZ7MKKmfmkW7F17FpQk7pMkAAldv
# 1  _98BmlWNSky-H-3b7cJphskAP0si
# 2  RsSYhYMSSEevknM1lziKd8kADSNi
# 3  DLIpJNhmqkiqfgUEt8AZtckALkzn
# 4  ghL0FByfsEWVIkGqKmMwlckADD7g
#
#                                            Task Name      Bucket Name  \
# 0                        , GLC HỌP THÁNG DUC THÁNG .  Meeting Support
# 1  , Họp review phần ngôn ngữ tiếng Anh trên webs...           Ticket
# 2                          , Họp TF dự án trồng rừng  Meeting Support
# 3                          , <pepsict>Kiểm tra email         Waitlist
# 4  , [Smartport] Triển khai dịch vụ bảo trì SMP v...           Ticket
#
#       Progress Priority Assigned To            Created By Created Date  \
# 0  In progress   Medium   IT/TuanPA  Gemadept IT Helpdesk   02/26/2024
# 1  In progress   Medium  IT/QuangHT  Gemadept IT Helpdesk   02/26/2024
# 2  In progress   Medium   IT/TuanPA  Gemadept IT Helpdesk   02/26/2024
# ...

# %%
df[571:585]
# Out:
#                           Task ID  \
# 571  3T5iOeLCa0mLW2OTHFl4CskACvQ3
# 572  IWbbRiG-ZUiMctRSO8S8W8kABFY-
# 573  0KQhEg8rW0qHQMizsmqCTckAOjSz
# 574  I4VuEQ6wM0-ynOXGAEbcAMkAEtMp
# 575  myYnT3Z4Hk2x-C6AlSfOeskAKKeC
# 576  6A2hwHIHEE2OV3Q5s3MMmMkAPVBl
# 577  5V-vkzjRVEWA2STDwtUZEckAL6o-
# 578  ANoExwT5I0i1RxfcrJsruskAO7P8
# 579  SA1Blyfr202IgJv_dkLSgskAJPx9
# 580  bjTmOm1k_k-F8pfth_WUf8kALRb1
# 581  WL6avO-H60-KXHYty1PWsckAFE9B
# 582  j8pQ8TdUNUyFtEl6uhJvJskAMaDo
# 583  pddz1SYqSEeeYL8fX9EC8MkAOdR8
# 584  jBRl031jHkOba265c30ML8kAPAY5
#
#                                              Task Name      Bucket Name  \
# 571                   (032c14), [GSC] HỌP MKT COC -  /  Meeting Support
# 572  (baf0ed), Họp về SP1.4_Báo cáo dự báo SL DT củ...           Ticket
# 573                   (3b624d), FW: THANH LÝ NGHỈ VIỆC           Ticket
# 574                   (d8b22f), HỌP PHỐI HỢP GSC - PIP  Meeting Support
# 575                         (ebcce1), Anh Long họp BCH  Meeting Support
# ...

# %%
df.head()
# Out:
#                         Task ID  \
# 0  yZ7MKKmfmkW7F17FpQk7pMkAAldv
# 1  _98BmlWNSky-H-3b7cJphskAP0si
# 2  RsSYhYMSSEevknM1lziKd8kADSNi
# 3  DLIpJNhmqkiqfgUEt8AZtckALkzn
# 4  ghL0FByfsEWVIkGqKmMwlckADD7g
#
#                                            Task Name      Bucket Name  \
# 0                        , GLC HỌP THÁNG DUC THÁNG .  Meeting Support
# 1  , Họp review phần ngôn ngữ tiếng Anh trên webs...           Ticket
# 2                          , Họp TF dự án trồng rừng  Meeting Support
# 3                          , <pepsict>Kiểm tra email         Waitlist
# 4  , [Smartport] Triển khai dịch vụ bảo trì SMP v...           Ticket
#
#       Progress Priority Assigned To            Created By Created Date  \
# 0  In progress   Medium   IT/TuanPA  Gemadept IT Helpdesk   02/26/2024
# 1  In progress   Medium  IT/QuangHT  Gemadept IT Helpdesk   02/26/2024
# 2  In progress   Medium   IT/TuanPA  Gemadept IT Helpdesk   02/26/2024
# ...

# %%
def split_name(name):
    return pd.Series(name.split(",", 1))
df[['First Name', 'Last Name']] = df['Task Name'].apply(split_name)

# %%
df
# Out:
#                            Task ID  \
# 0     yZ7MKKmfmkW7F17FpQk7pMkAAldv
# 1     _98BmlWNSky-H-3b7cJphskAP0si
# 2     RsSYhYMSSEevknM1lziKd8kADSNi
# 3     DLIpJNhmqkiqfgUEt8AZtckALkzn
# 4     ghL0FByfsEWVIkGqKmMwlckADD7g
# ...                            ...
# 1177  LTeUWl3LvESweZF9C2RgJskALj7C
# 1178  z6MFfU4IMUa7nAICaxenCskADUvx
# 1179  c0-k_AfbBESoHO_29U4WN8kABsdq
# 1180  5ZMM9GC86UG8T1x9UfEFLckAN6NQ
# 1181  8UsYELtkfk2CDuyKjHMj6MkAJpVX
#
#                                               Task Name  \
# 0                           , GLC HỌP THÁNG DUC THÁNG .
# 1     , Họp review phần ngôn ngữ tiếng Anh trên webs...
# 2                             , Họp TF dự án trồng rừng
# 3                             , <pepsict>Kiểm tra email
# 4     , [Smartport] Triển khai dịch vụ bảo trì SMP v...
# ...                                                 ...
# 1177                      Triển khai Planner phòng ITHO
# 1178             Rà soát, sắp xếp lại Rack phòng Server
# ...

# %%
df = df.drop('Task Name', axis=1)

# %%
df
# Out:
#                            Task ID                   Bucket Name     Progress  \
# 0     yZ7MKKmfmkW7F17FpQk7pMkAAldv               Meeting Support  In progress
# 1     _98BmlWNSky-H-3b7cJphskAP0si                        Ticket  In progress
# 2     RsSYhYMSSEevknM1lziKd8kADSNi               Meeting Support  In progress
# 3     DLIpJNhmqkiqfgUEt8AZtckALkzn                      Waitlist  In progress
# 4     ghL0FByfsEWVIkGqKmMwlckADD7g                        Ticket  In progress
# ...                            ...                           ...          ...
# 1177  LTeUWl3LvESweZF9C2RgJskALj7C                        MS 365    Completed
# 1178  z6MFfU4IMUa7nAICaxenCskADUvx  Network,Server/Firewall,ATTT    Completed
# 1179  c0-k_AfbBESoHO_29U4WN8kABsdq                     SmartPort    Completed
# 1180  5ZMM9GC86UG8T1x9UfEFLckAN6NQ        Moodle, Đào tạo, Event    Completed
# 1181  8UsYELtkfk2CDuyKjHMj6MkAJpVX        Moodle, Đào tạo, Event    Completed
#
# ...

# %%
df[555:585]
# Out:
#                           Task ID                Bucket Name   Progress  \
# 555  Z3kIUWX5RkiA8yXjbA3QkMkAAkJl  PC, Workstation, Helpdesk  Completed
# 556  iWyebC3b_0qmRH_rJA2Fa8kAMFLj         WebPortal, Website  Completed
# 557  FhMeQSsLtUGYM0aze8C5BMkAFM1r                     Ticket  Completed
# 558  0F5RcaNoQUq_kMWrgZeHdMkAAnnV                     Ticket  Completed
# 559  5FMairfQvUGg3iInVHxZC8kALZJm            Meeting Support  Completed
# 560  wyH_QLLje0i0mZfMv7ufy8kAM-Ks                  SmartPort  Completed
# 561  bfUOiFKaW0ucJEGGlaf22MkAGJVM          Oracle, E-Invoice  Completed
# 562  KTvJhkmCV0aAc9ydjCcd2skAL7Oh          Oracle, E-Invoice  Completed
# 563  6zCcziGPrkeZ7b8wT7JJ2skAHUZk          Oracle, E-Invoice  Completed
# 564  D-GD_A3k5kGGsE6RsVZSNckAJtYi          Oracle, E-Invoice  Completed
# 565  X3GTI7s8kkOUosRL4iEcuckACWkT          Oracle, E-Invoice  Completed
# 566  saZ_mcIy7UOJtiistc2yKskAAnbk          Oracle, E-Invoice  Completed
# ...

# %%
df['First Name']=df['First Name'].replace(r'\(\)', '', regex=True)

# %%
df['First Name'] = df['First Name'].str.replace(r'\(.*\)', '', regex=True)

# %%
df[555:585]
# Out:
#                           Task ID                Bucket Name   Progress  \
# 555  Z3kIUWX5RkiA8yXjbA3QkMkAAkJl  PC, Workstation, Helpdesk  Completed
# 556  iWyebC3b_0qmRH_rJA2Fa8kAMFLj         WebPortal, Website  Completed
# 557  FhMeQSsLtUGYM0aze8C5BMkAFM1r                     Ticket  Completed
# 558  0F5RcaNoQUq_kMWrgZeHdMkAAnnV                     Ticket  Completed
# 559  5FMairfQvUGg3iInVHxZC8kALZJm            Meeting Support  Completed
# 560  wyH_QLLje0i0mZfMv7ufy8kAM-Ks                  SmartPort  Completed
# 561  bfUOiFKaW0ucJEGGlaf22MkAGJVM          Oracle, E-Invoice  Completed
# 562  KTvJhkmCV0aAc9ydjCcd2skAL7Oh          Oracle, E-Invoice  Completed
# 563  6zCcziGPrkeZ7b8wT7JJ2skAHUZk          Oracle, E-Invoice  Completed
# 564  D-GD_A3k5kGGsE6RsVZSNckAJtYi          Oracle, E-Invoice  Completed
# 565  X3GTI7s8kkOUosRL4iEcuckACWkT          Oracle, E-Invoice  Completed
# 566  saZ_mcIy7UOJtiistc2yKskAAnbk          Oracle, E-Invoice  Completed
# ...

# %%
df['Task name'] = df['First Name'] + df['Last Name'].astype(str)

# %%
df=df.drop('First Name',axis=1)

# %%
df=df.drop('Last Name',axis=1)

# %%
df
# Out:
#                            Task ID                   Bucket Name     Progress  \
# 0     yZ7MKKmfmkW7F17FpQk7pMkAAldv               Meeting Support  In progress
# 1     _98BmlWNSky-H-3b7cJphskAP0si                        Ticket  In progress
# 2     RsSYhYMSSEevknM1lziKd8kADSNi               Meeting Support  In progress
# 3     DLIpJNhmqkiqfgUEt8AZtckALkzn                      Waitlist  In progress
# 4     ghL0FByfsEWVIkGqKmMwlckADD7g                        Ticket  In progress
# ...                            ...                           ...          ...
# 1177  LTeUWl3LvESweZF9C2RgJskALj7C                        MS 365    Completed
# 1178  z6MFfU4IMUa7nAICaxenCskADUvx  Network,Server/Firewall,ATTT    Completed
# 1179  c0-k_AfbBESoHO_29U4WN8kABsdq                     SmartPort    Completed
# 1180  5ZMM9GC86UG8T1x9UfEFLckAN6NQ        Moodle, Đào tạo, Event    Completed
# 1181  8UsYELtkfk2CDuyKjHMj6MkAJpVX        Moodle, Đào tạo, Event    Completed
#
# ...

# %%
Emails=['DatTQ@gemadept.com.vn','HuyTP@gemadept.com.vn','LocCQ@gemadept.com.vn','NhutNDQ@gemadept.com.vn','QuangHT@gemadept.com.vn','thaitd@gemadept.com.vn','TuanCQ@gemadept.com.vn','tuanpa@gemadept.com.vn','cangpt@gemadept.com.vn','DatTQ2@gemadept.com.vn','LuanNVM@gemadept.com.vn']

df['Email']=Emails
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[99], line 3
#       1 Emails=['DatTQ@gemadept.com.vn','HuyTP@gemadept.com.vn','LocCQ@gemadept.com.vn','NhutNDQ@gemadept.com.vn','QuangHT@gemadept.com.vn','thaitd@gemadept.com.vn','TuanCQ@gemadept.com.vn','tuanpa@gemadept.com.vn','cangpt@gemadept.com.vn','DatTQ2@gemadept.com.vn','LuanNVM@gemadept.com.vn']
# ----> 3 df['Email']=Emails
#
# File c:\Users\buidu\anaconda3\Lib\site-packages\pandas\core\frame.py:3950, in DataFrame.__setitem__(self, key, value)
#    3947     self._setitem_array([key], value)
#    3948 else:
#    3949     # set column
# -> 3950     self._set_item(key, value)
#
# File c:\Users\buidu\anaconda3\Lib\site-packages\pandas\core\frame.py:4143, in DataFrame._set_item(self, key, value)
#    4133 def _set_item(self, key, value) -> None:
#    4134     """
# ...

# %%
df['Email'] = 'example@gemadept.com.vn'

# %%
df
# Out:
#                            Task ID                   Bucket Name     Progress  \
# 0     yZ7MKKmfmkW7F17FpQk7pMkAAldv               Meeting Support  In progress
# 1     _98BmlWNSky-H-3b7cJphskAP0si                        Ticket  In progress
# 2     RsSYhYMSSEevknM1lziKd8kADSNi               Meeting Support  In progress
# 3     DLIpJNhmqkiqfgUEt8AZtckALkzn                      Waitlist  In progress
# 4     ghL0FByfsEWVIkGqKmMwlckADD7g                        Ticket  In progress
# ...                            ...                           ...          ...
# 1177  LTeUWl3LvESweZF9C2RgJskALj7C                        MS 365    Completed
# 1178  z6MFfU4IMUa7nAICaxenCskADUvx  Network,Server/Firewall,ATTT    Completed
# 1179  c0-k_AfbBESoHO_29U4WN8kABsdq                     SmartPort    Completed
# 1180  5ZMM9GC86UG8T1x9UfEFLckAN6NQ        Moodle, Đào tạo, Event    Completed
# 1181  8UsYELtkfk2CDuyKjHMj6MkAJpVX        Moodle, Đào tạo, Event    Completed
#
# ...

# %%
df.to_excel('C:\\Users\\buidu\\OneDrive\\Máy tính\\thisCode\\code\\PYthon_only\\task2\\newrp.xlsx', index=False)
