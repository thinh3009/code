# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import os
from PIL import Image
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
#xu ly anh
# Đường dẫn ảnh gốc và ảnh sau khi resize


input_path = r"C:\Users\Asus\Desktop\code\PYthon_only\selenium\AutoAddNews\hinh1.jpg"
output_path = r"C:\Users\Asus\Desktop\code\PYthon_only\selenium\AutoAddNews\resize.jpg"

# Mở ảnh
img = Image.open(input_path)

# Resize ảnh về đúng kích thước 390x270
resized_img = img.resize((390, 270))

# Lưu ảnh
resized_img.save(output_path)


# Thông tin đăng nhập và nội dung bài viết
cms_url = "https://hoadaumiennam.com.vn/admin"
time.sleep(4)
user = "admin"
password = "Dung 567@"

post_title = "Bài viết tự động"
post_content = "Đây là nội dung bài viết được tạo tự động bằng Selenium."
post_content2="Nghệ An: Thông xe kỹ thuật cầu vượt đường sắt"
post_content3='Công ty đạt lợi nhuận ổn định năm 2024 từ mảng dầu nhờn, nhưng mảng hóa chất tiếp tục đối mặt <img alt="CÔNG TY CỔ PHẦN XUẤT NHẬP KHẨU HOÁ DẦU MIỀN NAM" src="http://hoadaumiennam.com.vn/upload/elfinder/timthumb%20(38).jpeg" style="width: 390px; height: 390px;"> với thách thức. Về kế hoạch năm 2025, PLC đặt muc tiêu lợi nhuận trước thuế 140 tỷ đồng (gấp đôi so với kết quả năm 2024; tương đương với kế hoạch đầu năm 2024). Trong giai đoạn 2010 – 2024, lợi nhuận trước thuế thực tế trung bình hoàn thành 101% so với kế hoạch đầu năm.Chi tiết lợi nhuận trước thuế theo mảng (trước hợp nhất): Mảng dầu nhờn đạt 110 tỷ đồng (tăng 3% so với cùng kỳ năm trước), nguồn đóng góp ổn định và vững chắc; Mảng nhựa đường đạt 43 tỷ đồng (tăng 310%), mục tiêu tăng trưởng mạnh mẽ nhờ giải ngân đầu tư công; Mảng hóa chất đạt 2 tỷ đồng (so với lỗ ròng khoảng 46 tỷ đồng trong năm 2024), dự kiến cải thiện nhưng còn đối mặt với nhiều thách thức.Kết quả kinh doanh quý I/2025 sơ bộ cho thấy sự phục hồi mạnh với lợi nhuận trước thuế tăng 90% so với cùng kỳ 2024. Cụ thể, lợi nhuận trước thuế mảng dầu nhờn đạt 28 tỷ đồng (hoàn thiện 26% kế hoạch năm 2025), sản lượng cũng đạt 26% kế hoạch. Doanh số qua kênh Petrolimex tăng 9% so với cùng kỳ; doanh số qua kênh '
# Khởi tạo trình duyệt
driver = webdriver.Edge()  # Hoặc Firefox, Edge, etc.
driver.get(f"{cms_url}")
time.sleep(3)
# Đăng nhập
driver.find_element(By.XPATH, '//*[@id="username"]').send_keys(user)
time.sleep(5)
driver.find_element(By.XPATH, '//*[@id="password"]').send_keys(password)
time.sleep(6)
driver.find_element(By.XPATH, '/html/body/div[2]/div/div/form/button').click()
time.sleep(5)  # Đợi đăng nhập hoàn tất

# Truy cập trang tạo bài viết
driver.get(f"{cms_url}/index.php?com=news&act=man&type=tin-ve-nhua-duong")
time.sleep(3)
driver.find_element(By.XPATH,'/html/body/div/div[1]/section[2]/div[1]/a[1]').click()
time.sleep(5)
image_path = os.path.abspath(output_path)  # Đảm bảo đường dẫn tuyệt đối
upload_input = driver.find_element(By.ID, 'file-zone')  # hoặc By.NAME, By.XPATH, tùy giao diện
upload_input.send_keys(output_path)
driver.find_element(By.XPATH,'//*[@id="slugvi"]').send_keys(post_title)
time.sleep(5)
driver.find_element(By.XPATH,'//*[@id="tenvi"]').send_keys(post_content)
time.sleep(5)
driver.find_element(By.XPATH,'//*[@id="motavi"]').send_keys(post_content2)
time.sleep(5)

driver.execute_script("window.scrollTo(0, 600);")
#find iframe
iframe = driver.find_element(By.TAG_NAME, "iframe")
driver.switch_to.frame(iframe)
body = driver.find_element(By.TAG_NAME, "body")
body.clear()
body.send_keys(post_content3) 

# driver.find_element(By.XPATH,'/html/body').send_keys(post_content3)
time.sleep(4)

# 👉 QUAN TRỌNG: Quay lại main page trước khi tiếp tục scroll và nhập
driver.switch_to.default_content()
#seo
driver.execute_script("window.scrollTo(0, 700);")
driver.find_element(By.XPATH,'//*[@id="titlevi"]').send_keys('nhựa đường')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="keywordsvi"]').send_keys('nhựa đường')
time.sleep(2)
driver.find_element(By.XPATH,'//*[@id="descriptionvi"]').send_keys('nhựa đường')
time.sleep(2)
driver.execute_script("window.scrollTo(0, 500);")
time.sleep(3)
driver.find_element(By.XPATH,'//*[@id="cke_81"]').click()
time.sleep(3)
driver.find_element(By.CLASS_NAME,'cke_dialog_ui_button').click()
main_window = driver.current_window_handle
#Process data in image 
#duyet cua so moi
window_handles = driver.window_handles
print("Cửa sổ hiện tại:", driver.current_url)
# Chuyển sang cửa sổ mới (cửa sổ mới thường là handle cuối cùng)
time.sleep(10)
for handle in window_handles:
    if handle != main_window:
        driver.switch_to.window(handle)
        break

# Kiểm tra xem đã chuyển sang cửa sổ mới chưa
print("Cửa sổ hiện tại:", driver.current_url)  # Nên in ra URL của elFinder

# Đợi file xuất hiện và chọn file
#Find upload image
upload_button = WebDriverWait(driver, 10).until(
    EC.element_to_be_clickable((By.XPATH, '//*[@id="elfinder"]/div[1]/div[4]/div[3]'))  # Adjust XPATH
)
upload_button.click()
time.sleep(2)

file_input = WebDriverWait(driver, 10).until(
    EC.presence_of_element_located((By.XPATH, '//*[@id="elfinder"]/div[16]/div[2]/div/div[3]'))  # Adjust XPATH
)
file_input.send_keys(r'C:\Users\Asus\Desktop\code\PYthon_only\selenium\AutoAddNews\resize.jpg')
time.sleep(3)  # Wait for upload to complete
#check if image exists on data
try:
    yes_button=WebDriverWait(driver,5).until(
        EC.element_to_be_clickable((By.XPATH,'//*[@id="elfinder"]/div[16]/div[3]/div/button[1]'))
    )
    yes_button.click()
except Exception as e:
    # driver.find_element(By.XPATH,'//*[@id="elfinder"]/div[16]/div[3]/div/button[2]')
    pass

#click to accept image

# select_button_image = WebDriverWait(driver, 10).until(
#     EC.element_to_be_clickable((By.XPATH, '//*[@id="elfinder"]/div[16]/div[2]/div/div[3]/form/input'))  # Adjust XPATH//*[@id="elfinder"]/div[1]/div[5]/div[2]
# )
# select_button_image.click()
# time.sleep(2)

# image_path2 = os.path.abspath(output_path)  # Đảm bảo đường dẫn tuyệt đối
# upload_input = driver.find_element(By.XPATH, '//*[@id="elfinder"]/div[1]/div[5]/div[3]')  # hoặc By.NAME, By.XPATH, tùy giao diện
# upload_input.send_keys(output_path)
# file_to_select = WebDriverWait(driver, 10).until(
#     EC.element_to_be_clickable((By.CLASS_NAME, 'elfinder-cwd-file ui-corner-all ui-selectee ui-draggable-handle'))
# )
# Action=ActionChains(driver)
# Action.double_click(file_to_select).perform()
# time.sleep(3)

# Chuyển về cửa sổ chính
driver.switch_to.window(main_window)

# Kiểm tra xem đã quay lại chưa
print("Cửa sổ hiện tại:", driver.current_url)  # Nên in ra URL của trang chính

driver.find_element(By.XPATH,'//*[@id="cke_1481_uiElement"]').click()
time.sleep(4)
#---------------------------------SAVE--------------------------------#
# driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/section[2]/form/div[1]/button[1]').click()
# Out:
# Error sending stats to Plausible: error sending request for url (https://plausible.io/api/event)
# Cửa sổ hiện tại: https://hoadaumiennam.com.vn/admin/index.php?com=news&act=add&type=tin-ve-nhua-duong&p=1
# Cửa sổ hiện tại: https://hoadaumiennam.com.vn/admin/elfinder/index.php?CKEditor=noidungvi&CKEditorFuncNum=1&langCode=vi#elf_l1_Lw
# Cửa sổ hiện tại: https://hoadaumiennam.com.vn/admin/index.php?com=news&act=add&type=tin-ve-nhua-duong&p=1
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[1], line 153
#     150 # Kiểm tra xem đã quay lại chưa
#     151 print("Cửa sổ hiện tại:", driver.current_url)  # Nên in ra URL của trang chính
# --> 153 driver.find_element(By.XPATH,'//*[@id="cke_1481_uiElement"]').click()
#     154 time.sleep(4)
#
# File c:\Users\Asus\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
# ...

# %%
from bs4 import BeautifulSoup
import requests
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import os
from PIL import Image
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

cms_url = "https://hoadaumiennam.com.vn/admin/elfinder/index.php?CKEditor=noidungvi&CKEditorFuncNum=1&langCode=vi#elf_l1_Lw"
driver = webdriver.Edge()  # Hoặc Firefox, Edge, etc.
driver.get(f"{cms_url}")
time.sleep(3)
htmltxt = requests.get('https://hoadaumiennam.com.vn/admin/elfinder/index.php?CKEditor=noidungvi&CKEditorFuncNum=1&langCode=vi#elf_l1_Lw').text
soup = BeautifulSoup(htmltxt, 'lxml')
detail = soup.select('div',class_='elfinder-cwd-filename')
