# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\buidu\\OneDrive\\Máy tính\\code2\\PYthon_only\\pandas\\data\\players_18_Copy.csv")
df
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 3         176580  https://sofifa.com/player/176580/luis-suarez/1...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 17949     235352  https://sofifa.com/player/235352/tommy-kassemo...
# 17950     237463  https://sofifa.com/player/237463/adam-kelsey/1...
# 17951     238308  https://sofifa.com/player/238308/leslie-sackey...
# 17952     238813  https://sofifa.com/player/238813/josh-lundstra...
# 17953     240404  https://sofifa.com/player/240404/jack-keeble/1...
#
#               short_name                            long_name  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# ...

# %%
df.fillna(0,inplace=True)
df["wage_eur"] = df["wage_eur"].map(int)
df['wage_eur'].sum()
# Out:
# 201861500

# %%
df['sofifa_id'][df['real_face']=='Yes']
# Out:
# 0         20801
# 1        158023
# 2        167495
# 3        176580
# 4        190871
#           ...
# 15721    232544
# 15735    232928
# 16043    224263
# 17028    231438
# 17219    222931
# Name: sofifa_id, Length: 1236, dtype: int64

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 3     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 4     190871  https://sofifa.com/player/190871/neymar-da-sil...
#
#           short_name                            long_name player_positions  \
# 0  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           LW, ST
# 1           L. Messi       Lionel Andrés Messi Cuccittini               RW
# 2           M. Neuer                   Manuel Peter Neuer               GK
# 3          L. Suárez             Luis Alberto Suárez Díaz               ST
# 4             Neymar        Neymar da Silva Santos Júnior               LW
#
#    overall  potential    value_eur  wage_eur  age  ... nation_position  \
# ...

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name',
#        'player_positions', 'overall', 'potential', 'value_eur', 'wage_eur',
#        'age', 'dob', 'height_cm', 'weight_kg', 'club_team_id', 'club_name',
#        'league_name', 'league_level', 'club_position', 'club_jersey_number',
#        'club_loaned_from', 'club_joined', 'club_contract_valid_until',
#        'nationality_id', 'nationality_name', 'nation_team_id',
#        'nation_position', 'nation_jersey_number', 'preferred_foot',
#        'weak_foot', 'skill_moves', 'international_reputation', 'work_rate',
#        'body_type', 'real_face', 'release_clause_eur'],
#       dtype='object')

# %%
df[['short_name','dob']].head()
# Out:
#           short_name        dob
# 0  Cristiano Ronaldo   2/5/1985
# 1           L. Messi  6/24/1987
# 2           M. Neuer  3/27/1986
# 3          L. Suárez  1/24/1987
# 4             Neymar   2/5/1992

# %%
df.describe()
# Out:
#            sofifa_id       overall     potential     value_eur       wage_eur  \
# count   17954.000000  17954.000000  17954.000000  1.795400e+04   17954.000000
# mean   207482.676785     66.244124     71.184193  2.372106e+06   11243.260555
# std     32431.256118      6.994141      6.090664  5.337550e+06   22531.803908
# min        16.000000     46.000000     46.000000  0.000000e+00       0.000000
# 25%    192367.500000     62.000000     67.000000  3.000000e+05    2000.000000
# 50%    214005.500000     66.000000     71.000000  6.750000e+05    4000.000000
# 75%    231403.750000     71.000000     75.000000  2.100000e+06   10000.000000
# max    254073.000000     94.000000     94.000000  1.230000e+08  575000.000000
#
#                 age     height_cm     weight_kg   club_team_id  league_level  \
# count  17954.000000  17954.000000  17954.000000   17954.000000  17954.000000
# mean      25.164532    181.269244     75.378189   42671.334076      1.392225
# ...

# %%
df[df.age==40]
# Out:
#        sofifa_id                                         player_url  \
# 1230      137854  https://sofifa.com/player/137854/marco-storari...
# 2039        3665  https://sofifa.com/player/3665/benjamin-nivet/...
# 2614       17605  https://sofifa.com/player/17605/timmy-simons/1...
# 3456      176900  https://sofifa.com/player/176900/mayer-candelo...
# 11933      18745  https://sofifa.com/player/18745/mark-tyler/180002
# 13654      53832  https://sofifa.com/player/53832/michael-brown/...
# 16354     151208  https://sofifa.com/player/151208/wayne-brown/1...
#
#        short_name                    long_name player_positions  overall  \
# 1230   M. Storari                Marco Storari               GK       76
# 2039     B. Nivet               Benjamin Nivet          CAM, CM       74
# 2614    T. Simons                 Timmy Simons      CDM, CM, CB       73
# 3456   M. Candelo  Mayer Andrés Candelo García              CAM       72
# ...

# %%
df[df.age==df['age'].max()]
# Out:
#        sofifa_id                                         player_url  \
# 17946      11728  https://sofifa.com/player/11728/barry-richards...
#
#           short_name         long_name player_positions  overall  potential  \
# 17946  B. Richardson  Barry Richardson               GK       46         46
#
#        value_eur  wage_eur  age  ... nation_position  nation_jersey_number  \
# 17946     2000.0      1000   47  ...               0                   0.0
#
#        preferred_foot  weak_foot skill_moves international_reputation  \
# 17946           Right          2           1                        1
#
#            work_rate      body_type  real_face release_clause_eur
# 17946  Medium/Medium  Stocky (185+)         No                0.0
#
# [1 rows x 35 columns]

# %%
df[df.age==df['age'].min()]
# Out:
#        sofifa_id                                         player_url  \
# 10738     234925  https://sofifa.com/player/234925/kik-pierie/18...
# 12814     240507  https://sofifa.com/player/240507/angel-gomes/1...
# 14317     240661  https://sofifa.com/player/240661/emanuel-vigna...
# 15867     239085  https://sofifa.com/player/239085/erling-haland...
# 15959     240904  https://sofifa.com/player/240904/javier-maria-...
# 15965     241046  https://sofifa.com/player/241046/jonas-romero/...
# 16285     239689  https://sofifa.com/player/239689/max-sprang/18...
# 17096     237125  https://sofifa.com/player/237125/valentin-barb...
# 17175     240419  https://sofifa.com/player/240419/roberto-strec...
# 17199     240941  https://sofifa.com/player/240941/lenny-pintor/...
# 17636     234066  https://sofifa.com/player/234066/johan-hove/18...
#
#          short_name                             long_name player_positions  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=17954, step=1)

# %%
df.set_index('sofifa_id',inplace=True) #dat gia tri index

# %%
df.head()
# Out:
#                                                   player_url  \
# sofifa_id
# 20801      https://sofifa.com/player/20801/c-ronaldo-dos-...
# 158023     https://sofifa.com/player/158023/lionel-messi/...
# 167495     https://sofifa.com/player/167495/manuel-neuer/...
# 176580     https://sofifa.com/player/176580/luis-suarez/1...
# 190871     https://sofifa.com/player/190871/neymar-da-sil...
#
#                   short_name                            long_name  \
# sofifa_id
# 20801      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# 158023              L. Messi       Lionel Andrés Messi Cuccittini
# 167495              M. Neuer                   Manuel Peter Neuer
# 176580             L. Suárez             Luis Alberto Suárez Díaz
# 190871                Neymar        Neymar da Silva Santos Júnior
#
#           player_positions  overall  potential    value_eur  wage_eur  age  \
# sofifa_id
# 20801               LW, ST       94         94   95500000.0    575000   32
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#        sofifa_id                                         player_url  \
# 0          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 1         158023  https://sofifa.com/player/158023/lionel-messi/...
# 2         167495  https://sofifa.com/player/167495/manuel-neuer/...
# 3         176580  https://sofifa.com/player/176580/luis-suarez/1...
# 4         190871  https://sofifa.com/player/190871/neymar-da-sil...
# ...          ...                                                ...
# 17949     235352  https://sofifa.com/player/235352/tommy-kassemo...
# 17950     237463  https://sofifa.com/player/237463/adam-kelsey/1...
# 17951     238308  https://sofifa.com/player/238308/leslie-sackey...
# 17952     238813  https://sofifa.com/player/238813/josh-lundstra...
# 17953     240404  https://sofifa.com/player/240404/jack-keeble/1...
#
#               short_name                            long_name  \
# 0      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro
# ...

# %%
df.dtypes
# Out:
# sofifa_id                      int64
# player_url                    object
# short_name                    object
# long_name                     object
# player_positions              object
# overall                        int64
# potential                      int64
# value_eur                    float64
# wage_eur                       int64
# age                            int64
# dob                           object
# height_cm                      int64
# weight_kg                      int64
# club_team_id                 float64
# club_name                     object
# league_name                   object
# league_level                 float64
# club_position                 object
# club_jersey_number           float64
# club_loaned_from              object
# club_joined                   object
# club_contract_valid_until    float64
# nationality_id                 int64
# nationality_name              object
# nation_team_id               float64
# ...
