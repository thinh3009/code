# %%
print("hello")
# Out:
# hello

# %% [markdown]
# 1. Tim kiem tuyen tinh

# %%
import random


def sinhmang(n):
    mang = []
    for i in range(n):
        so_ngauNhien = random.randint(-100, 100)
        mang.append(so_ngauNhien)
    return mang


def timtuyentinh(mang, x):

    for i in range(len(mang)):
        if mang[i] == x:
            return i
    return -1


def main():
    mang = sinhmang(20)
    print(mang)

    x = int(input("nhap so muon tim: "))
    vitri = timtuyentinh(mang, x)
    if vitri != -1:
        print(f"gia tri {x} duoc tim thay tai vi tri {vitri}")
    else:
        print("khong tim thay")


if __name__ == "__main__":
    main()
# Out:
# [61, 31, 76, 3, 2, -16, 19, -38, 30, -83, -84, 50, 58, 2, -21, 19, 58, -27, 74, 35]
# gia tri 31 duoc tim thay tai vi tri 1

# %% [markdown]
# 1. vd ve tim kiem tuyen tinh
# cho nhom hoc sinh gom 10 ban voi tuoi tu 1-->20 do tuoi khac nhau tim ban co tuoi nho nhat

# %%
import random


def sinhngaunhien(n, tuoi):
    mang = []
    for i in range(n):
        mang.append(random.randint(1, 10))
        print(mang[i], end=' ')
    print()
    for j in range(len(mang)):
        if tuoi == mang[j]:
            return j
    return -1


if __name__ == "__main__":
    n = 10
    tuoi = int(input("nhap so tuoi muon tim: "))
    vitri = sinhngaunhien(n, tuoi)
    if vitri != -1:
        print(f"gia tri {tuoi} duoc tim thay tai vi tri {vitri}")
    else:
        print("khong tim thay")
# Out:
# 9 7 3 3 4 6 6 9 2 4
# gia tri 4 duoc tim thay tai vi tri 4

# %% [markdown]
# 2. tim kiem nhi phan

# %%
import random


def sinhmangtangdan(n):
    mang = []
    sodautien = random.randint(-100, 100)
    # You need to append the first random number to the list
    mang.append(sodautien)
    for i in range(1, n):
        tang = random.randint(1, 10)
        so = mang[i-1]+tang
        mang.append(so)
    return mang


def timnhiphan(mang, x):
    trai = 0
    phai = len(mang)-1
    while trai <= phai:
        giua = (trai+phai)//2
        if mang[giua] == x:  # You need to use mang[giua] instead of [giua]
            return giua
        if x < mang[giua]:
            phai = giua-1
        else:
            trai = giua+1
    return -1


def main():
    mang = sinhmangtangdan(20)
    print(mang)
    x = int(input("nhap gia tri can tim"))
    vitri = timnhiphan(mang, x)
    if vitri != -1:
        print(f"tim thay phan tu {x} tai vi tri {vitri}")
    else:
        print("khong tim thay")


if __name__ == "__main__":
    main()
# Out:
# [10, 20, 30, 39, 47, 48, 58, 68, 71, 73, 76, 84, 94, 104, 109, 114, 121, 129, 131, 135]
# khong tim thay

# %% [markdown]
# 3. Interchange Sort
# * Xuất phát từ đầu dãy, tìm tất các các nghịch thế chứa
# phần tử này, triệt tiêu chúng bằng cách đổi chỗ 2 phần
# tử trong cặp nghịch thế.
# * Lặp lại xử lý trên với phần tử kế trong dãy.

# %%
import random


def interchange_sort(n):
    mang = []
    for i in range(n):
        so_ngauNhien = random.randint(1, 25)
        mang.append(so_ngauNhien)
    # thuat toan interchange_sort
    n = len(mang)
    for i in range(n-1):
        for j in range(i+1, n):
            if mang[i] > mang[j]:
                mang[i], mang[j] = mang[j], mang[i]
    return mang


if __name__ == "__main__":
    n = int(input("nhap so ptu: "))
    print(interchange_sort(n))
# Out:
# [2, 3, 3, 13, 20]

# %%
def interchange_sort(a):
    n = len(a)
    for i in range(n-1):
        for j in range(i+1, n):
            if a[i] > a[j]:
                a[i], a[j] = a[j], a[i]


if __name__ == "__main__":
    mang = [3, 4, 5, 4, 54, 56, 67, 7, 87, 65]

# %% [markdown]
# 4. sap xep chon
# * Tại vị trí đầu tiên của dãy, chọn phần tử nhỏ nhất trong
# N phần tử trong dãy hiện hành ban đầu và đưa phần tử
# này về vị trí đầu dãy hiện hành.
# * Xem dãy hiện hành chỉ còn N-1 phần tử của dãy hiện
# hành ban đầu. Bắt đầu từ vị trí thứ 2, chọn phần tử nhỏ
# nhất trong số N-1 phần tử kể trên và đưa nó về vị trí đầu
# của dãy gồm N-1 phần tử đang xét.
# * Lặp lại quá trình trên cho dãy hiện hành... đến khi dãy
# hiện hành chỉ còn 1 phần tử.

# %%
import random


def sinhngaunhien(n):
    mang = []
    for i in range(n):
        songaunhien = random.randint(1, 100)
        mang.append(songaunhien)
    return mang


def sapxepchon(mang):
    n = len(mang)
    for i in range(n-1):  # n-1: la gia tri nho nhat cuoi cung khi gia tri nho nhat duoc tim ra
        vitriMin = i
        for j in range(i+1, n):  # i+1: la gia tri ke sau gia tri nho nhat
            if mang[vitriMin] > mang[j]:
                vitriMin = j
        mang[i], mang[vitriMin] = mang[vitriMin], mang[i]
        print(i+1, "-", mang)


def main():
    mang = sinhngaunhien(10)
    print('mang ban dau: ', mang)
    sapxepchon(mang)
    print("mang sau khi sap xep: ", mang)


if __name__ == "__main__":
    main()
# Out:
# mang ban dau:  [89, 88, 5, 59, 13, 17, 11, 77, 24, 89]
# 1 - [5, 88, 89, 59, 13, 17, 11, 77, 24, 89]
# 2 - [5, 11, 89, 59, 13, 17, 88, 77, 24, 89]
# 3 - [5, 11, 13, 59, 89, 17, 88, 77, 24, 89]
# 4 - [5, 11, 13, 17, 89, 59, 88, 77, 24, 89]
# 5 - [5, 11, 13, 17, 24, 59, 88, 77, 89, 89]
# 6 - [5, 11, 13, 17, 24, 59, 88, 77, 89, 89]
# 7 - [5, 11, 13, 17, 24, 59, 77, 88, 89, 89]
# 8 - [5, 11, 13, 17, 24, 59, 77, 88, 89, 89]
# 9 - [5, 11, 13, 17, 24, 59, 77, 88, 89, 89]
# mang sau khi sap xep:  [5, 11, 13, 17, 24, 59, 77, 88, 89, 89]

# %% [markdown]
# 5. sap xep noi bot
# * Hoán đổi vị trí của cặp phần tử liền kề cho tới khi không đổi được nữa thì dừng

# %%
def sinhngaunhien(n):
    mang = []
    for i in range(n):
        songaunhien = random.randint(0, 100)
        mang.append(songaunhien)
    return mang


def sapxepnoibot(mang):
    for i in range(len(mang)):  # i=[0,n-1]
        tiep_tuc = False

        for j in range(len(mang)-2, i-1, -1):  # j=[n-2,i],
            if mang[j] > mang[j+1]:
                mang[j], mang[j+1] = mang[j+1], mang[j]
                tiep_tuc = True
        print(i+1, '-', mang)

        if tiep_tuc == False:
            break


def main():
    mang = sinhngaunhien(10)
    print("mang ban dau la: ", mang)
    sapxepnoibot(mang)
    print("mang sau khi sap xep: ", mang)


if __name__ == "__main__":
    main()
# Out:
# mang ban dau la:  [60, 10, 83, 55, 49, 41, 68, 97, 90, 7]
# 1 - [7, 60, 10, 83, 55, 49, 41, 68, 97, 90]
# 2 - [7, 10, 60, 41, 83, 55, 49, 68, 90, 97]
# 3 - [7, 10, 41, 60, 49, 83, 55, 68, 90, 97]
# 4 - [7, 10, 41, 49, 60, 55, 83, 68, 90, 97]
# 5 - [7, 10, 41, 49, 55, 60, 68, 83, 90, 97]
# 6 - [7, 10, 41, 49, 55, 60, 68, 83, 90, 97]
# mang sau khi sap xep:  [7, 10, 41, 49, 55, 60, 68, 83, 90, 97]

# %% [markdown]
# 6. Insert sort
# * giống xếp bài
# * Ban đầu coi như phần tử đầu tiên đã sắp xếp.
# * So sánh phần tử thứ 2 với phần tử đầu tiên để đổi chỗ
# nếu cần để sao cho 2 phần tử này được sắp xếp theo thứ
# tự chỉ định.
# * Tìm vị trí để chèn phần tử thứ 3 của dãy hiện hành vào
# dãy 2 phần tử đầu đã được sắp xếp ở trên sao cho dãy
# vẫn được sắp xếp đúng thứ tự.

# %%
def sinhngaunhien(n):
    mang = []
    for i in range(n):
        songaunhien = random.randint(0, 100)
        mang.append(songaunhien)
    return mang


def insertSort(mang):
    n = len(mang)
    for i in range(1, n):
        temp = mang[i]
        j = i
        while j > 0 and mang[j-1] > temp:
            mang[j] = mang[j-1]
            j = j-1
        mang[j] = temp
        print(i, '-', mang)


if __name__ == "__main__":
    n = int(input("nhap so ptu: "))
    sinh = sinhngaunhien(n)
    print(sinh)
    insertSort(sinh)
    print("mang da sap xep: ", sinh)
# Out:
# [26, 75, 100, 57, 66, 61]
# 1 - [26, 75, 100, 57, 66, 61]
# 2 - [26, 75, 100, 57, 66, 61]
# 3 - [26, 57, 75, 100, 66, 61]
# 4 - [26, 57, 66, 75, 100, 61]
# 5 - [26, 57, 61, 66, 75, 100]
# mang da sap xep:  [26, 57, 61, 66, 75, 100]

# %% [markdown]
# 7. Quick sort
# * Ý tưởng cơ bản của thuật toán Quick Sort là chọn một phần tử trong mảng làm pivot (giá trị chốt), sau đó chia mảng thành hai phần: Các phần tử có giá trị nhỏ hơn pivot và các phần tử có giá trị lớn hơn hoặc bằng pivot. Sau đó, tiếp tục sử dụng thuật toán Quick Sort đệ quy trên hai mảng được tạo ra.

# %%
def sinhngaunhien(n):
    mang = []
    for i in range(n):
        songaunhien = random.randint(0, 100)
        mang.append(songaunhien)
    return mang


def PhanVung(mang, duoi, tren):
    i = duoi-1  # chi muc phan tu nho hon moc
    moc = mang[tren]  # co the lay gia tri moc bat ki
    # dua lan luot cac phan tu nho hon moc ve tren
    for j in range(duoi, tren):
        if mang[j] < moc:
            i = i+1
            mang[i], mang[j] = mang[j], mang[i]
        # end if
    # end for
    mang[i+1], mang[tren] = mang[tren], mang[i+1]
    return i+1
# end def


def quickSort(mang, duoi, tren):
    if duoi < tren:
        vitri = PhanVung(mang, duoi, tren)
        quickSort(mang, duoi, vitri-1)
        quickSort(mang, vitri+1, tren)
    # end if


if __name__ == "__main__":
    n = int(input("nhap so ptu: "))
    sinh = sinhngaunhien(n)
    print(sinh)
    quickSort(sinh, 0, len(sinh)-1)
    print("mang sau khi sap xep", sinh)
# Out:
# [20, 18, 29, 66, 58, 53]
# mang sau khi sap xep [18, 53, 20, 58, 29, 66]

# %% [markdown]
# 7. Quick Sort2

# %%
import random


def sinhngaunhien(n):
    mang = []
    for i in range(n):
        songaunhien = random.randint(0, 100)
        mang.append(songaunhien)
    return mang


def quickSort2(mang):
    if len(mang) > 1:
        nhohon = []
        bang = []
        lonhon = []
        p = mang[0]
        for x in mang:
            if x < p:
                nhohon.append(x)
            elif x == p:
                bang.append(x)
            else:
                lonhon.append(x)
        return quickSort2(nhohon) + bang+quickSort2(lonhon)
    else:
        return mang


if __name__ == "__main__":
    n = int(input("nhap so ptu: "))
    sinh = sinhngaunhien(n)
    print(sinh)
    mangmoi = quickSort2(sinh)
    print("mang sau khi xep: ", mangmoi)
# Out:
# [2, 56, 38, 4, 78, 40, 57]
# mang sau khi xep:  [2, 4, 38, 40, 56, 57, 78]

# %% [markdown]
# 8. Merger sort

# %%
import random


def sinhngaunhien(n):
    mang = []
    for i in range(n):
        songaunhien = random.randint(0, 100)
        mang.append(songaunhien)
    return mang


def sapxeptron(mang):
    if len(mang) > 1:
        giua = len(mang)//2
        mangtrai = mang[0:giua]
        mangphai = mang[giua:]

        sapxeptron(mangtrai)
        sapxeptron(mangphai)
        i = j = k = 0  # tron mang
        while (i < len(mangtrai) and j < len(mangphai)):
            if mangtrai[i] < mangphai[j]:
                mang[k] = mangtrai[i]
                i = i+1
            else:
                mang[k] = mangphai[j]
                j = j+1
            k += 1
        while i < len(mangtrai):
            mang[k] = mangtrai[i]
            i = i+1
            k = k+1
        while j < len(mangphai):
            mang[k] = mangphai[j]
            j = j+1
            k = k+1


if __name__ == "__main__":
    mang = sinhngaunhien(10)
    print("mang khi chua sap xep: ", mang)
    sapxeptron(mang)
    print("mang sau khi sap xep: ", mang)
# Out:
# mang khi chua sap xep:  [88, 48, 69, 16, 24, 96, 50, 88, 20, 11]
# mang sau khi sap xep:  [11, 16, 20, 24, 48, 50, 69, 88, 88, 96]

# %% [markdown]
# 9. Linked list
#
# * Dễ chèn và xóa: Thêm hoặc xóa một nút trong danh sách liên kết có thể được thực hiện mà không cần di chuyển tất cả các phần tử khác, điều này làm giảm độ phức tạp so với mảng trong một số trường hợp.
#
# * Kích thước linh hoạt: Danh sách liên kết có thể mở rộng hoặc co lại mà không cần phải cấp phát lại bộ nhớ như mảng.
#
# * Tuy nhiên, danh sách liên kết cũng có một số nhược điểm, chẳng hạn như tiêu tốn thêm bộ nhớ do việc lưu trữ liên kết và yêu cầu truy cập tuần tự.

# %%
class Nut:
    def __init__(self, giatri):
        self.giatri = giatri
        self.nutketiep = None


class DsLienKet:
    def __init__(self):
        self.dau = None
        self.duoi = None

    def inDS(self):
        stt = 0
        hientai = self.dau
        kq = 'DS['
        while (hientai != None):
            stt += 1
            if stt == 1:
                kq += ' ' + str(hientai.giatri)
            else:
                kq += ' -> '+str(hientai.giatri)
            hientai = hientai.nutketiep
        kq += ' ]'
        print(kq)

    def them(self, giatri):
        nut = Nut(giatri)
        if self.dau == None:
            self.dau = nut
            self.duoi = nut
        else:
            self.duoi.nutketiep = nut
            self.duoi = nut

    def chen(self, chimuc, giatri):
        nut=Nut(giatri)
        truoc=None
        hientai=self.dau
        i=0
        while i<chimuc and hientai!=None:
            i +=1
            truoc=hientai
            hientai=hientai.nutketiep
        if truoc ==None:
            #them vao dau ds
            nut.nutketiep=self.dau
            self.dau=nut
            if self.duoi ==None:
                self.duoi = nut
        else:
            if hientai==None:
                #them vao cuoi ds
                self.duoi.nutketiep=nut
                self.duoi=nut
            else:
                #them vao giua ds
                truoc.nutketiep=nut
                nut.nutketiep=hientai



    def tim(self, giatri):
        hientai=self.dau
        vitri=0
        while(hientai!=None and hientai.giatri!=giatri):
            hientai = hientai.nutketiep
            vitri+=1
        if hientai==None:
            return None
        else:
            return vitri
        

    def xoa(self, giatri):
        hientai=self.dau
        truoc=None
        while(hientai!=None and hientai.giatri!=giatri):
            truoc=hientai
            hientai=hientai.nutketiep
        if hientai!=None:
            #tim thay 
            if hientai==self.dau and hientai==self.duoi:
                #xoa phan tu duy nhat
                self.dau = self.duoi=None
            elif hientai==self.dau:
                #xoa phan tu dau tien khong duy nhat
                self.dau = self.dau.nutketiep
            elif hientai==self.duoi:
                #xoa phan tu duoi khong duy nhat
                truoc.nutketiep=None
                self.duoi=truoc
            else:
                #xoa o giua
                truoc.nutketiep=hientai.nutketiep
            del hientai


    def capnhat(self, vitri, giatri):
        hientai=self.dau
        i=0
        while(i<vitri and hientai!=None):
            i+=1
            hientai=hientai.nutketiep
        if hientai!=None:
            hientai.giatri=giatri

    def xoahet(self):
        hientai = self.dau
        self.dau= self.duoi=None
        while(hientai!=None):
            tam=hientai
            hientai=hientai.nutketiep
            del tam



if __name__ == "__main__":

    ds = DsLienKet()
    ds.inDS()
    # them
    print('a: them -------------------')
    so = 12
    print(f'them {so}')
    ds.them(so)
    ds.inDS()

    so = 1
    print(f'them {so}')
    ds.them(so)
    ds.inDS()

    #chen
    print('b:chen---------------------')
    so=93
    vtri=0
    print(f"chen {so} vao vi tri {vtri}")
    ds.chen(vtri,so)
    ds.inDS()

    so=3
    vtri=1
    print(f"chen {so} vao vi tri {vtri}")
    ds.chen(vtri,so)
    ds.inDS()
    #tim
    print('c: tim---------------------')
    ds.inDS()
    so=12
    print(f'tim {so}')
    vt=ds.tim(so)
    print(f'so {so} tai vi tri {vt}')
    #xoa
    print("d: xoa--------------------")
    so=93
    print(f'xoa {so}')
    ds.xoa(so)
    ds.inDS()

    so=1
    print(f'xoa {so}')
    ds.xoa(so)
    ds.inDS()
    #cap nhat
    print("e:cap nhat--------------------")
    vt=0
    giatri=2
    print('cap nhat vitri {vt} voi giatri {giatri}')
    ds.capnhat(vt,giatri)
    ds.inDS()
    #xoa het
    print('f.xoa het----------------')
    print("xoa het")
    ds.xoahet()
    ds.inDS()
# Out:
# DS[ ]
# a: them -------------------
# them 12
# DS[ 12 ]
# them 1
# DS[ 12 -> 1 ]
# b:chen---------------------
# chen 93 vao vi tri 0
# DS[ 93 -> 12 -> 1 ]
# chen 3 vao vi tri 1
# DS[ 93 -> 3 -> 12 -> 1 ]
# c: tim---------------------
# DS[ 93 -> 3 -> 12 -> 1 ]
# tim 12
# so 12 tai vi tri 2
# d: xoa--------------------
# xoa 93
# DS[ 3 -> 12 -> 1 ]
# xoa 1
# DS[ 3 -> 12 ]
# e:cap nhat--------------------
# cap nhat vitri {vt} voi giatri {giatri}
# DS[ 2 -> 12 ]
# f.xoa het----------------
# xoa het
# DS[ ]

# %% [markdown]
# 10. Ngăn xếp
# * Một stack (ngăn xếp) là một cấu trúc dữ liệu trừu tượng tuân thủ nguyên tắc "Last In, First Out" (LIFO). Điều này có nghĩa là phần tử cuối cùng được thêm vào stack sẽ là phần tử được lấy ra đầu tiên. Cụ thể, stack hỗ trợ hai hoạt động chính:

# %%
class Nganxep():
    pass
    def __init__(self):
        self.danhsach=[]
    def larong(self):
        return len(self.danhsach)==0
    def __str__(self):
        kq='Ngan xep ['
        stt=0
        for x in self.danhsach:
            stt+=1
            if stt==1:
                kq+str(x)
            else:
                kq=kq+' -> '+ str(x)

        kq= kq+']'
        return kq
    def dayvao(self,giatri):
        self.danhsach.insert(0,giatri)

    def layra(self):
        if self.larong():
            return None
        else:
            return self.danhsach.pop(0)

if __name__=='__main__':
    stack=Nganxep()
    print(stack)
    print('------- day vao---------')
    for i in range(1,6):
        print(f'* day vao {i}')
        stack.dayvao(i)
        print(stack)
    print('------- lay ra ---------')
    while not stack.larong():
        gt=stack.layra()
        print(f'* lay ra -> {gt}')
        print(stack)
    print("*"*50)
# Out:
# Ngan xep []
# ------- day vao---------
# * day vao 1
# Ngan xep []
# * day vao 2
# Ngan xep [ -> 1]
# * day vao 3
# Ngan xep [ -> 2 -> 1]
# * day vao 4
# Ngan xep [ -> 3 -> 2 -> 1]
# * day vao 5
# Ngan xep [ -> 4 -> 3 -> 2 -> 1]
# ------- lay ra ---------
# * lay ra -> 5
# Ngan xep [ -> 3 -> 2 -> 1]
# * lay ra -> 4
# Ngan xep [ -> 2 -> 1]
# * lay ra -> 3
# Ngan xep [ -> 1]
# * lay ra -> 2
# Ngan xep []
# * lay ra -> 1
# Ngan xep []

# %% [markdown]
# 10. Queue

# %%
from queue import Queue
if __name__ =="__main__":
    q=Queue(-1)
    print('----- push ------')
    for i in range(1,6):
        print(f'put {i}')
        q.put(i)
    print('----- get ------')
    while not q.empty():
        gt=q.get()
        print(f'get -> {gt}')
# Out:
# ----- push ------
# put 1
# put 2
# put 3
# put 4
# put 5
# ----- get ------
# get -> 1
# get -> 2
# get -> 3
# get -> 4
# get -> 5

# %% [markdown]
# 11. Stack va Queue dung dslk

# %%
class Nut:
    def __init__(self,giatri):
        self.giatri=giatri
        self.nutketiep=None
class Dslk:
    def __init__(self):
        self.dau=None
        self.duoi=None
    def __str__(self):
        kq=''
        stt=0
        hientai=self.dau
        while hientai != None:
            stt=stt+1
            if stt==1:
                kq=kq+str(hientai.giatri)
            else:
                kq=kq+' -> '+str(hientai.giatri)
            hientai=hientai.nutketiep
        return kq
    def themdau(self,giatri):
        nut=Nut(giatri)
        if self.dau == None:
            self.dau=nut
            self.duoi=nut
        else:
            nut.nutketiep=self.dau
            self.dau=nut

    def themduoi(self,giatri):
        nut = Nut(giatri)
        if self.dau==None:
            self.dau=nut
            self.duoi=nut
        else:
            self.duoi.nutketiep=nut
            self.duoi=nut
    def laydau(self):
        if self.dau==None:
            return None
        else:
            return self.dau.giatri
    def xoadau(self):
        tam=self.dau
        if self.dau==self.duoi:
            self.dau=None
            self.duoi=None
        else:
            self.dau=self.dau.nutketiep
        del tam
#ngan xep     
class NganXep:
        def __init__(self):
            self.danhsach=Dslk()
        def larong(self):
            return self.danhsach.dau==None
        def __str__(self):
            kq='Ngan xep ['
            kq=kq+str(self.danhsach)
            kq=kq+']'
            return kq
        def dayvao(self,giatri):
            self.danhsach.themdau(giatri)
        def layra(self):
            if self.larong():
                return None
            else:
                kq=self.danhsach.laydau()
                self.danhsach.xoadau()
                return kq
#hang doi
class HangDoi:
    def __init__(self):
        self.danhsach=Dslk()

    def __str__(self):
        kq='Hang doi ['
        kq=kq+str(self.danhsach)
        kq=kq+']'
        return kq
    def larong(self):
        return self.danhsach.dau==None
    def xephang(self,giatri):
        self.danhsach.themduoi(giatri)
    def rahang(self):
        if self.larong():
            return None
        else:
            kq=self.danhsach.laydau()
            self.danhsach.xoadau()
            return kq
if __name__ == "__main__":
    nganxep=NganXep()
    print(nganxep)
    print('-----day vao------')
    for i in range(1,6):
        print(f'* day vao {i}')
        nganxep.dayvao(i)
        print(nganxep)
    print('-----lay ra-------')
    while not nganxep.larong():
        gt=nganxep.layra()
        print(f'* lay ra -> {gt}')
        print(nganxep)
    print('*'*20)
    hangdoi=HangDoi()
    print(hangdoi)
    print('-----xep vao------')
    for i in range(1,6):
        print(f'* day vao {i}')
        hangdoi.xephang(i)
        print(hangdoi)
    print('-----lay ra-------')
    while not hangdoi.larong():
        gt=hangdoi.rahang()
        print(f'* lay ra -> {gt}')
        print(hangdoi)
# Out:
# Ngan xep []
# -----day vao------
# * day vao 1
# Ngan xep [1]
# * day vao 2
# Ngan xep [2 -> 1]
# * day vao 3
# Ngan xep [3 -> 2 -> 1]
# * day vao 4
# Ngan xep [4 -> 3 -> 2 -> 1]
# * day vao 5
# Ngan xep [5 -> 4 -> 3 -> 2 -> 1]
# -----lay ra-------
# * lay ra -> 5
# Ngan xep [4 -> 3 -> 2 -> 1]
# * lay ra -> 4
# Ngan xep [3 -> 2 -> 1]
# * lay ra -> 3
# Ngan xep [2 -> 1]
# * lay ra -> 2
# Ngan xep [1]
# * lay ra -> 1
# Ngan xep []
# ********************
# Hang doi []
# -----xep vao------
# * day vao 1
# Hang doi [1]
# * day vao 2
# Hang doi [1 -> 2]
# * day vao 3
# Hang doi [1 -> 2 -> 3]
# * day vao 4
# Hang doi [1 -> 2 -> 3 -> 4]
# * day vao 5
# Hang doi [1 -> 2 -> 3 -> 4 -> 5]
# -----lay ra-------
# * lay ra -> 1
# Hang doi [2 -> 3 -> 4 -> 5]
# * lay ra -> 2
# Hang doi [3 -> 4 -> 5]
# * lay ra -> 3
# Hang doi [4 -> 5]
# * lay ra -> 4
# Hang doi [5]
# * lay ra -> 5
# Hang doi []

# %% [markdown]
# * do thi

# %%
import math


def taodothi():
    f = open('dothi.txt')
    sodinh = int(f.readline().strip())
    caccanh = f.readline()
    f.close()

    dt = [[0 for _ in range(sodinh)] for _ in range(sodinh)]
    return dt
    

dt = taodothi()
print(dt)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       8     dt=[[0 for _ in range(sodinh)] for _ in range(sodinh)]
#       9     return dt
# ---> 11 dt=taodothi()
#      12 print(dt)
#
# Cell In[6], line 4, in taodothi()
#       2 def taodothi():
#       3     f=open('dothi.txt')
# ----> 4     sodinh=int(f.readline().strip())
#       5     caccanh=f.readline()
#       6     f.close()
#
# ValueError: invalid literal for int() with base 10: ''
